# %% [markdown]
# *Daniela Lancheros*

# %% [markdown]
# *Juana Valeria Pinzón*

# %% [markdown]
# # ***Taller*** ***3***

# %% [markdown]
# # *1.*

# %% [markdown]
# $$
# m \vec{a}=-m \vec{g}+\vec{N}-\gamma\|\vec{v}\|^{2} \hat{v}
# $$

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# %%
g=9.8 #Gravedad (m/s^2)
theta=np.radians(30)
m=10e-3 ##Masa carros en kg
v_0=0
H=0 ## altura incial (m)
gamma=0.7 ## coeficiente de friccion (Kg/m)

# %% [markdown]
# $$
#  \frac{dv}{dt}=g\sin{θ}-\frac{\gamma}{m_{total}}\|\vec{v}\|^{2}
# $$

# %%
def ecuacion_movimiento(t,Y,gamma,masa):
  x,v=Y
  return ([v,g*np.sin(theta)-((gamma*(abs(v)**2))/masa)])

# %%
def y_cero(t,y,gamma,masa):
  return y[0]-30
y_cero.terminal=True
y_cero.direction=1

# %%
def masas_variables(masa_carros,masas):
  t_caida=np.array([])
  solucion=[]
  for M in masas:
    m_total=m+M
    sol=solve_ivp(ecuacion_movimiento,y0=np.array([H,v_0]),t_span=(0,100),args=[gamma,m_total],max_step=0.1,events=[y_cero])
    solucion.append(sol.y[0])
    tiempo_caida=sol.t[-1]
    t_caida=np.append(tiempo_caida,t_caida)

  return t_caida,solucion

# %%
masas=np.linspace(0.2,1,100)
tiempos_caidas,soluciones=masas_variables(m,masas)

# %%
plt.plot(masas,tiempos_caidas,".-")
plt.ylabel('tiempo de caida')
plt.xlabel('Masas variables')
plt.title('Masa vs tiempo')
plt.grid()

# %%
fig, ax = plt.subplots()
y=[i*np.sin(theta) for i in soluciones]
x=[i*np.cos(theta) for i in soluciones]
colores = plt.cm.viridis(masas / max(masas))
scat=ax.scatter([i[0] for i in x],[i[0] for i in y],color=colores)
def update(frame):
      x_new=[x[i][frame]for i in range(len(masas))]
      y_new=[y[i][frame] for i in range(len(masas))]
      scat.set_offsets(np.c_[x_new, y_new])
      return scat,

anim = animation.FuncAnimation(fig=fig, func=update, frames=40, interval=100)

# %% [markdown]
# ## 2.

# %%
mu = 39.4234021
a= 0.38709893
e = 0.20563069

x_cero = a * (1 + e)
y_cero = 0
vx_cero = 0
vy_cero = np.sqrt(mu / a * (1 - e) / (1 + e))

# %%
def orbita_mercurio(t, y):
  alpha = 1.09778201e-2
  x, y, vx, vy = y
  r = np.linalg.norm([x,y])
  return [vx, vy, -mu * x  / r**3 * (1 + alpha / r**2), -mu * y  / r**3 * (1 + alpha / r**2)]

# %%
sol =solve_ivp(orbita_mercurio, t_span=(0.,10.), y0=[x_cero,y_cero,vx_cero,vy_cero], method='RK45', max_step=1e-3,rtol=1e-9,atol=1e-12)

# %%
t_d= np.linspace(sol.t[0],sol.t[-1],300)
Y= sol.sol(t_d)
x_mercurio,y_mercurio=sol.y[0],sol.y[1]
fig = plt.figure();
plt.xlim(x_mercurio.min(),x_mercurio.max()+0.5)
plt.ylim(y_mercurio.min(),y_mercurio.max()+0.5)

line = plt.plot(x[0],y[0])
def func(frame):
    point.set_offsets(Y[:2,frame])
    if frame>1:
        line.set_data(x_dense[:frame+1],y_dense[:frame+1])
    return point,line
anim = animation.FuncAnimation(fig,func,frames=range(len(t_dense)),interval=10)

#plt.figure(figsize=(12, 12))
#plt.plot(sol.y[0], sol.y[1])
#plt.xlabel('x (UA)')
#plt.ylabel('y (UA)')
#plt.grid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-f9c49fdcb854> in <cell line: 2>()
#       1 t_d= np.linspace(sol.t[0],sol.t[-1],300)
# ----> 2 Y= sol.sol(t_d)
#       3 x_mercurio,y_mercurio=sol.y[0],sol.y[1]
#       4 fig = plt.figure();
#       5 plt.xlim(x_mercurio.min(),x_mercurio.max()+0.5)
#
# TypeError: 'NoneType' object is not callable

# %%
r= np.sqrt(sol.y[0]**2+sol.y[1]**2)
v2 = sol.y[2]**2 + sol.y[3]**2
energia=v2+(mu/r)

t_un_año=np.argmin(np.abs(sol.t-1))

plt.figure(figsize=(12, 8))
plt.plot(sol.t[:t_un_año], energia[:t_un_año])
plt.title('Energía vs. Tiempo en un año')
plt.xlabel('Tiempo (años)')
plt.ylabel('Energía')
plt.grid()

# %% [markdown]
# ### 2.2

# %%
def mercurio_cerca(t,y):
  x,y,vx,vy=y
  return x*vx+y*vy
mercurio_cerca.terminal=False
mercurio_cerca.direction=0
sol = solve_ivp(orbita_mercurio, t_span=(0,10.), y0=[x_cero,y_cero,vx_cero,vy_cero], method='RK45', max_step = 1e-4,events=[mercurio_cerca])

#ángulo
angulos=np.arctan2(sol.y_events[0][:,1],sol.y_events[0][:,0])

# %%
tiempo=sol.t_events[0]
periastro=np.array([])
t_apoastro=np.array([])
t_periastro=np.array([])
apoastro=np.array([])
for i,angulo in enumerate(angulos):
  if 0<=angulo<=np.pi/2 or 0<=angulo<=3*np.pi/2:
    apoastro=np.append(angulo,apoastro)
    t_apoastro=np.append(tiempo[i],t_apoastro)
  else:
    periastro=np.append(angulo,periastro)
    t_periastro=np.append(tiempo[i],t_periastro)

# Estandarizar
periastro-=np.pi
apoastro-=2*np.pi

# %%
apoastro_arcsec,periastro_arcsec=(3600*np.rad2deg(apoastro)),(3600*np.rad2deg(periastro))

# %%
#Grafica angulo vs tiempo

##Apoastro

plt.scatter(t_apoastro,apoastro_arcsec,label="Ángulos Apoastro")
plt.scatter(t_periastro,periastro_arcsec,label="Ángulos Periastro",ls="dotted")
plt.xlabel("Tiempo (años)")
plt.ylabel("Angulos (arcsec)")
plt.grid()
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b83ddad90244> in <cell line: 5>()
#       3 ##Apoastro
#       4
# ----> 5 plt.scatter(t_apoastro,apoastro_arcsec,label="Ángulos Apoastro")
#       6 plt.scatter(t_periastro,periastro_arcsec,label="Ángulos Periastro",ls="dotted")
#       7 plt.xlabel("Tiempo (años)")
#
# NameError: name 't_apoastro' is not defined

# %%
# Pendiente
coefficients=np.polyfit(t_periastro,periastro_arcsec,1)
coefficients[0]

# %% [markdown]
# 3.

# %%
def ecuacion_schrodinger(x,y,E):
  f,d_f=y
  return ([d_f,(x**2*f)-2*E*f])

# %%
# Configuración del rango de energías y condiciones iniciales

Energias = np.arange(0, 10, 0.01)

def encontrar_energias(Energias,ecuacion,condiciones):
  condicion = 10
  soluciones=[]
  energias=[]
  for E in Energias:
      sol = solve_ivp(ecuacion_schrodinger, t_span=(0, 6), y0=condiciones, args=[E],max_step=1e-3)
      if abs(sol.y[0, -1]) < condicion and abs(sol.y[1, -1]) < condicion:
          soluciones.append(sol.y[0])
          energias.append(E)
          if len(energias) >= 5:
              break
  return energias,soluciones

# %%
## Energias simetricas:
energias_forma_simetrica,solucion_simetrica=encontrar_energias(Energias,ecuacion_schrodinger,[1,0])
energias_forma_simetrica
# Out:
# [0.5, 2.5, 4.5, 6.5, 8.5]

# %%
## Energias antisimetricas:Ç
energias_forma_antisimetrica,solucion_antisimetrica=encontrar_energias(Energias,ecuacion_schrodinger,[0,1])
energias_forma_antisimetrica
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-6b05e48309a2> in <cell line: 2>()
#       1 ## Energias antisimetricas:Ç
# ----> 2 energias_forma_antisimetrica,solucion_antisimetrica=encontrar_energias(Energias,ecuacion_schrodinger,[0,1])
#       3 energias_forma_antisimetrica
#
# <ipython-input-52-55c33235dcbe> in encontrar_energias(Energias, ecuacion, condiciones)
#       8   energias=[]
#       9   for E in Energias:
# ---> 10       sol = solve_ivp(ecuacion_schrodinger, t_span=(0, 6), y0=condiciones, args=[E],max_step=1e-3)
#      11       if abs(sol.y[0, -1]) < condicion and abs(sol.y[1, -1]) < condicion:
#      12           soluciones.append(sol.y[0])
#
# /usr/local/lib/python3.10/dist-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     653     status = None
#     654     while status is None:
# --> 655         message = solver.step()
#     656
#     657         if solver.status == 'finished':
#
# /usr/local/lib/python3.10/dist-packages/scipy/integrate/_ivp/base.py in step(self)
#     195         else:
#     196             t = self.t
# --> 197             success, message = self._step_impl()
#     198
#     199             if not success:
#
# /usr/local/lib/python3.10/dist-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     142             h_abs = np.abs(h)
#     143
# --> 144             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                                    self.B, self.C, self.K)
#     146             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#
# /usr/local/lib/python3.10/dist-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      60     """
#      61     K[0] = f
# ---> 62     for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63         dy = np.dot(K[:s].T, a[:s]) * h
#      64         K[s] = fun(t + c * h, y + dy)
#
# KeyboardInterrupt:

# %%
def energias_probar(energias,soluciones):
  fig, ax = plt.subplots()
  for i,E in enumerate(energias):
    plt.plot(soluciones[i],label=f"energia:{E:.3f}")
    plt.ylim(-3,-3)
  plt.legend()
  plt.grid()

# %%
energias_probar(energias_forma_simetrica,solucion_simetrica)

# %%
energias_probar(energias_forma_antisimetrica,solucion_antisimetrica)
